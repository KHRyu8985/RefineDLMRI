# %%
import os, sys, h5py
sys.path.append("train")

import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (10,10)
from run_refine_vcc_spirit import runvccspirit
from run_refine_spirit import runspirit
from run_refine_espirit import runespirit

# %%
im_cs2, im_d2, im_r2, im_f = runvccspirit(12, 18, lam=5, R=3, nacs=23, im_type='Knee_fs', option='cs')
# Out:
# Calibrating SPIRIT........
# ic| 'prefiltering w/ opth'
# 98/750 kernels used
# 100%|██████████| 30/30 [00:01<00:00, 23.58it/s]
# Calibration Finished ...... 2.18 seconds
# Iter [10/500], residual:0.9391947369130722
# Iter [20/500], residual:0.00481237629787192
# Elapsed time: 3.059924364089966

# %%
im_cs4, im_d4, im_r4, im_f = runvccspirit(12, 18, lam=5, R=4, nacs=21, im_type='Knee_fs', option='cs')
# Out:
# Calibrating SPIRIT........
# ic| 'prefiltering w/ opth'
# 98/750 kernels used
# 100%|██████████| 30/30 [00:01<00:00, 23.47it/s]
# Calibration Finished ...... 2.15 seconds
# Iter [10/500], residual:0.919686192088051
# Iter [20/500], residual:0.004775211387787859
# Elapsed time: 3.0146172046661377

# %%
im_cs6, im_d6, im_r6, im_f = runvccspirit(12, 18, lam=5, R=6, nacs=21, im_type='Knee_fs', option='cs')
# Out:
# Calibrating SPIRIT........
# ic| 'prefiltering w/ opth'
# 98/750 kernels used
# 100%|██████████| 30/30 [00:01<00:00, 22.38it/s]
# Calibration Finished ...... 2.26 seconds
# Iter [10/500], residual:0.6814021483089909
# Iter [20/500], residual:0.0036863970764479657
# Elapsed time: 3.093608856201172

# %%
vmax_val = 1.4 # PD: 4 
fig, ((ax1, ax2, ax3)) = plt.subplots(nrows=1,ncols=3,figsize=(15,5), dpi=600)


ax1.imshow(sp.resize(np.abs(im_f),(200,200)), cmap='gray',vmax=3)
ax1.axis('off')


ax2.imshow(sp.resize(np.abs(im_cs4),(200,200)), cmap='gray',vmax=vmax_val)
ax2.axis('off')

           
ax3.imshow(sp.resize(np.abs(im_cs6),(200,200)), cmap='gray',vmax=vmax_val)
ax3.axis('off')


fig.tight_layout()

# %%
vmax_val = 3 # PD: 4 
fig, ((ax1, ax2, ax3)) = plt.subplots(nrows=1,ncols=3,figsize=(15,5), dpi=600)


ax1.imshow(sp.resize(np.abs(im_d2),(200,200)), cmap='gray',vmax=vmax_val)
ax1.axis('off')


ax2.imshow(sp.resize(np.abs(im_d4),(200,200)), cmap='gray',vmax=vmax_val)
ax2.axis('off')

           
ax3.imshow(sp.resize(np.abs(im_d6),(200,200)), cmap='gray',vmax=vmax_val)
ax3.axis('off')


fig.tight_layout()

# %%
vmax_val = 3 # PD: 4 
fig, ((ax1, ax2, ax3)) = plt.subplots(nrows=1,ncols=3,figsize=(15,5), dpi=600)


ax1.imshow(sp.resize(np.abs(im_r2),(200,200)), cmap='gray',vmax=vmax_val)
ax1.axis('off')


ax2.imshow(sp.resize(np.abs(im_r4),(200,200)), cmap='gray',vmax=vmax_val)
ax2.axis('off')

           
ax3.imshow(sp.resize(np.abs(im_r6),(200,200)), cmap='gray',vmax=vmax_val)
ax3.axis('off')


fig.tight_layout()
